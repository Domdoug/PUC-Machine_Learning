# %% [markdown]
# # <font color='blue'>Especialização em Ciência de Dados - PUC-Rio</font>
# # Machine Learning
# ## Exercício 1: Análise Exploratória e Pré-processamento de Dados

# %% [markdown]
# ---
#
#
# __Alunos:__ <br>
#         Cícero Felipe Ricci Bressane <br>
#         José Douglas Nascimento <br>
#         Ronaldo Costa <br>
#         Victor Mouffron Carvalho Machado
#
# ---

# %% [markdown]
# # Escolha um dataset simples (preferencialmente do UCI Machine Learning Repository - https://archive.ics.uci.edu/ml/index.php) e treine a análise exploratória e o pré-processamento de dados com os comandos aprendidos em aula#

# %% [markdown]
# O dataset escolhido foi obtido no Kaggle no link: https://www.kaggle.com/jealousleopard/goodreadsbooks. Trata-se de um dataset com review de livros da plaforma Goodreads (https://www.goodreads.com/) em que cada linha representa um livro. Os atributos do dataset são:
#
# __bookID__ - Identificador do livro <br>
# __title__ - Título do Livro <br>
# __authors__ - Autores do livro, separados por hífen <br>
# __average_rating__ - Avaliação média <br>
# __isbn__ - Código ISBN <br>
# __isbn13__ - Código ISBN de 13 dígitos <br>
# __language_code__ - Código da língua do livro <br>
# __num_pages__ - Número de páginas do livro <br>
# __ratings_count__ - Quantidade de avaliações (notas) <br>
# __text_reviews_count__ - Quantidade de avaliações em texto <br>
#
# ## Vamos começar a análise!##
#
# ![Livros](img/livraria.jpg)

# %% [markdown]
# ## Importar bibliotecas e dataset ##

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy


# dataset apresenta cinco linhas com mais vírgulas do que o correto
# parâmetro error_bad_lines vai pular essas linhas
df = pd.read_csv('data/books.csv',error_bad_lines = False) 
df.head()
# Out:
# b'Skipping line 4012: expected 10 fields, saw 11\nSkipping line 5688: expected 10 fields, saw 11\nSkipping line 7056: expected 10 fields, saw 11\nSkipping line 10601: expected 10 fields, saw 11\nSkipping line 10668: expected 10 fields, saw 11\n'
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       3  Harry Potter and the Sorcerer's Stone (Harry P...
# 3       4  Harry Potter and the Chamber of Secrets (Harry...
# 4       5  Harry Potter and the Prisoner of Azkaban (Harr...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling-Mary GrandPré            4.56  0439785960  9780439785969
# 1  J.K. Rowling-Mary GrandPré            4.49  0439358078  9780439358071
# 2  J.K. Rowling-Mary GrandPré            4.47  0439554934  9780439554930
# 3                J.K. Rowling            4.41  0439554896  9780439554893
# 4  J.K. Rowling-Mary GrandPré            4.55  043965548X  9780439655484
#
#   language_code  # num_pages  ratings_count  text_reviews_count
# 0           eng          652        1944099               26249
# 1           eng          870        1996446               27613
# 2           eng          320        5629932               70390
# 3           eng          352           6267                 272
# 4           eng          435        2149872               33964

# %% [markdown]
# ## Análise exploratória ##

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13714 entries, 0 to 13713
# Data columns (total 10 columns):
# bookID                13714 non-null int64
# title                 13714 non-null object
# authors               13714 non-null object
# average_rating        13714 non-null float64
# isbn                  13714 non-null object
# isbn13                13714 non-null int64
# language_code         13714 non-null object
# # num_pages           13714 non-null int64
# ratings_count         13714 non-null int64
# text_reviews_count    13714 non-null int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 1.0+ MB

# %% [markdown]
# __Análise:__ <br>
# Nosso dataset possui 13714 linhas e nenhum campo apresenta valores nulos!

# %%
df.describe()
# Out:
#              bookID  average_rating        isbn13   # num_pages  \
# count  13714.000000    13714.000000  1.371400e+04  13714.000000
# mean   22159.859195        3.930620  9.764017e+12    342.402727
# std    13700.926816        0.357893  3.987679e+11    252.650165
# min        1.000000        0.000000  8.987060e+09      0.000000
# 25%    10619.250000        3.770000  9.780345e+12    196.000000
# 50%    21321.500000        3.960000  9.780613e+12    301.000000
# 75%    33311.750000        4.130000  9.780940e+12    421.000000
# max    47709.000000        5.000000  9.790008e+12   6576.000000
#
#        ratings_count  text_reviews_count
# count   1.371400e+04        13714.000000
# mean    1.776540e+04          533.632128
# std     1.129572e+05         2529.006691
# min     0.000000e+00            0.000000
# 25%     8.300000e+01            7.000000
# 50%     6.305000e+02           40.000000
# 75%     4.742250e+03          222.000000
# max     5.629932e+06        93619.000000

# %% [markdown]
# __Análise:__ <br>
# As avaliações variam em uma escala de 0 a 5 e a mediana é 3,96.<br>
# Parece haver uma inconsistência no número de páginas, pois temos livros com zero páginas!<br>
# A maioria das pessoas deixam apenas uma avaliação em nota e não escrevem reviews em texto.

# %%
df['language_code'].unique()
# Out:
# array(['eng', 'en-US', 'spa', 'fre', 'en-GB', 'mul', 'ger', 'ara', 'por',
#        'grc', 'en-CA', 'enm', 'jpn', 'dan', 'zho', 'nl', 'ita', 'lat',
#        'srp', 'rus', 'tur', 'msa', 'swe', 'glg', 'cat', 'wel', 'heb',
#        'nor', 'gla', 'ale'], dtype=object)

# %% [markdown]
# __Análise:__ <br>
#
# Existem livros de diversas línguas no dataset, mas parece haver algumas incosistências. Temos 'eng','eng-GB','eng-US' e 'eng-CA' como livros de língua inglesa. Mas ao que se referem os livros apenas com 'eng'? Durante o pré-processamento podemos converter todos para um único padrão!

# %%
df.corr(method = 'pearson')
# Out:
#                       bookID  average_rating    isbn13  # num_pages  \
# bookID              1.000000       -0.042510 -0.001610    -0.012872
# average_rating     -0.042510        1.000000  0.000453     0.167388
# isbn13             -0.001610        0.000453  1.000000    -0.011723
# # num_pages        -0.012872        0.167388 -0.011723     1.000000
# ratings_count      -0.081236        0.041234  0.004835     0.028408
# text_reviews_count -0.087670        0.036695  0.007260     0.034171
#
#                     ratings_count  text_reviews_count
# bookID                  -0.081236           -0.087670
# average_rating           0.041234            0.036695
# isbn13                   0.004835            0.007260
# # num_pages              0.028408            0.034171
# ratings_count            1.000000            0.863467
# text_reviews_count       0.863467            1.000000

# %% [markdown]
# __Análise:__ <br>
#
# Variáveis não possuem muita correlação linear, exceto as variáveis __text_reviews_count__ e __ratings_count__.

# %%
# autores com maiores médias de review
df.groupby('authors').mean()['average_rating'].nlargest(20)
# Out:
# authors
# Aaron Rosenberg-Christopher Cook                                                                            5.0
# Aristophanes-F.W. Hall-W.M. Geldart                                                                         5.0
# Chris    Green-Chris Wright-Paul Douglas Gardner                                                            5.0
# Chris Jiggins-Pablo Andrade-Eduardo Cueva                                                                   5.0
# Dennis Adler-R.L. Wilson                                                                                    5.0
# Ian        Martin-Katie Elliott                                                                             5.0
# James E. Campbell                                                                                           5.0
# James E. Ingram-Lori Grove                                                                                  5.0
# Jean-Paul Gabilliet-François Gallix-Janice Fiamengo-Raphaelle Costa de Beauregard-Priscilla Morin-Ollier    5.0
# John  Diamond                                                                                               5.0
# Julie Sylvester-David Sylvester                                                                             5.0
# Laura Driscoll-Alisa Klayman-Grodsky-Eric     Weiner                                                        5.0
# Middlesex Borough Heritage Committee                                                                        5.0
# Nicholas    Evans-Rhonda  Evans                                                                             5.0
# R. McL. Wilson                                                                                              5.0
# Ross Garnaut                                                                                                5.0
# Sara Barton-Wood                                                                                            5.0
# Sheri Rose Shepherd                                                                                         5.0
# Svetlana Alpers                                                                                             5.0
# Todd Davis-Marc Frey                                                                                        5.0
# Name: average_rating, dtype: float64

# %%
sns.boxplot('# num_pages',data=df)
plt.title('Boxplot do número de páginas por livro')
plt.show()

# %%
sns.pairplot(df)
plt.title('Pairplot dos atributos')
plt.show()

# %% [markdown]
# # Pré-processamento#

# %% [markdown]
# __Vamos padronizar os livros de língua inglesa!__

# %%
languages_to_convert = ['eng','en-US','en-GB','en-CA']
df.language_code[df['language_code'].isin(languages_to_convert)] = 'en'
df['language_code'].unique()
# Out:
# array(['en', 'spa', 'fre', 'mul', 'ger', 'ara', 'por', 'grc', 'enm',
#        'jpn', 'dan', 'zho', 'nl', 'ita', 'lat', 'srp', 'rus', 'tur',
#        'msa', 'swe', 'glg', 'cat', 'wel', 'heb', 'nor', 'gla', 'ale'],
#       dtype=object)

# %% [markdown]
# __Vamos obter o nome do primeiro autor e colocar em uma nova variável!__

# %%
df['first_author'] = df['authors'].str.split('-').str[0]
df['first_author'].unique()
# Out:
# array(['J.K. Rowling', 'W. Frederick Zimmerman', 'Douglas Adams', ...,
#        'David C. Hendrickson', 'Alisa Kwitney', 'Brian Froud'],
#       dtype=object)

# %% [markdown]
# __Vamos criar uma variável binária que indica se um livro tem mais de 300 páginas__

# %%
from sklearn.preprocessing import Binarizer

binarizer = Binarizer(threshold=300)
df['more_than_300'] = binarizer.fit_transform(df['# num_pages'].values.reshape(-1,1))
df.sample(10)
# Out:
#        bookID                                              title  \
# 11322   37852                                     Marilyn Manson
# 6390    19108                                         Dead Souls
# 8411    26581    Sleeping Beauty Trilogy (Sleeping Beauty  #1-3)
# 212       447                                        Moon Palace
# 6770    20868          Sea of Fire (Tom Clancy's Op-Center  #10)
# 13407   46434                                   The Light of Day
# 11044   36572                                To Love a Dark Lord
# 12387   42512  We Were Soldiers Once... and Young: Ia Drang -...
# 10405   33734                             Getting Rid of Bradley
# 2791     8643        Strange Sounds: Music  Technology & Culture
#
#                                                 authors  average_rating  \
# 11322                                     Kurt Reighley            3.39
# 6390   Nikolai Gogol-Richard Pevear-Larissa Volokhonsky            3.99
# 8411                          A.N. Roquelaure-Anne Rice            3.99
# 212                                         Paul Auster            3.98
# 6770              Jeff Rovin-Tom Clancy-Steve Pieczenik            3.89
# 13407                                       Eric Ambler            3.74
# 11044                                       Anne Stuart            3.83
# 12387                Harold G. Moore-Joseph L. Galloway            4.31
# 10405                                   Jennifer Crusie            3.70
# 2791                                  Timothy D. Taylor            3.77
#
#              isbn         isbn13 language_code  # num_pages  ratings_count  \
# 11322  0312181337  9780312181338            en          192            112
# 6390   1400043190  9781400043194            en          445            365
# 8411   0452156610  9780452156616            en          724          10728
# 212    0140115854  9780140115857            en          320          14594
# 6770   0425190919  9780425190913            en          400           1203
# 13407  0375726799  9780375726798            en          224            742
# 11044  0380776049  9780380776047            en          409           1203
# 12387  034547581X  9780345475817            en          480          21192
# 10405  1551668653  9781551668659            en          248          12254
# 2791   0415936845  9780415936842            en          278             26
#
#        text_reviews_count       first_author  more_than_300
# 11322                   5      Kurt Reighley              0
# 6390                   45      Nikolai Gogol              1
# 8411                  223    A.N. Roquelaure              1
# 212                   475        Paul Auster              1
# 6770                   23         Jeff Rovin              1
# 13407                  85        Eric Ambler              0
# 11044                  91        Anne Stuart              1
# 12387                 430    Harold G. Moore              1
# 10405                 585    Jennifer Crusie              0
# 2791                    0  Timothy D. Taylor              0

# %% [markdown]
# __Normalizando o número de ratings__

# %%
from sklearn.preprocessing import MinMaxScaler


df['ratings_normalized'] = MinMaxScaler().fit_transform(df['ratings_count'].values.reshape(-1,1))
df.sample(10)
# Out:
#        bookID                                              title  \
# 4446    13486                         How to Think Theologically
# 12863   44244       The Beleaguered City: The Vicksburg Campaign
# 7756    24283                                     Les Misérables
# 4351    13146                                       Black Friday
# 2547     7724                The Metamorphosis and Other Stories
# 10839   35484  The Ring And The Fire: Stories From Wagner's N...
# 7767    24307  The Pen Is Mightier Than The Sword (The Amazin...
# 8428    26666  Things Pondered: From the Heart of a Lesser Woman
# 9719    31319           They Do It With Mirrors (Miss Marple #6)
# 10063   32505  The Closers (Harry Bosch  #11; Harry Bosch Uni...
#
#                                                 authors  average_rating  \
# 4446                      Howard W. Stone-James O. Duke            3.65
# 12863                                      Shelby Foote            4.22
# 7756   Victor Hugo-Charles E. Wilbour-James K. Robinson            4.29
# 4351                                    James Patterson            3.67
# 2547                      Franz Kafka-Stanley Appelbaum            4.03
# 10839                                Clyde Robert Bulla            3.67
# 7767                            Anne Mazer-Monica Gesue            3.96
# 8428                                         Beth Moore            4.09
# 9719                                    Agatha Christie            3.75
# 10063                                  Michael Connelly            4.12
#
#              isbn         isbn13 language_code  # num_pages  ratings_count  \
# 4446   0800638182  9780800638184            en          142            222
# 12863  0679601708  9780679601708            en          368            258
# 7756   0449300021  9780449300022            en          400           4565
# 4351   0446609323  9780446609326            en          480           9539
# 2547   0486290301  9780486290300            en           88           2404
# 10839  0690702523  9780690702521            en          135              3
# 7767   0439178827  9780439178822            en          128           1063
# 8428   0805427317  9780805427318            en          160            282
# 9719   0007120877  9780007120871            en          284            415
# 10063  0446699551  9780446699556            en          432          28571
#
#        text_reviews_count        first_author  more_than_300  \
# 4446                   20     Howard W. Stone              0
# 12863                  24        Shelby Foote              1
# 7756                  340         Victor Hugo              1
# 4351                  214     James Patterson              1
# 2547                  122         Franz Kafka              0
# 10839                   1  Clyde Robert Bulla              0
# 7767                   19          Anne Mazer              0
# 8428                   24          Beth Moore              0
# 9719                   46     Agatha Christie              0
# 10063                1215    Michael Connelly              1
#
#        ratings_normalized
# 4446         3.943209e-05
# 12863        4.582649e-05
# 7756         8.108446e-04
# 4351         1.694337e-03
# 2547         4.270034e-04
# 10839        5.328661e-07
# 7767         1.888122e-04
# 8428         5.008941e-05
# 9719         7.371315e-05
# 10063        5.074839e-03

# %% [markdown]
# # Agora pesquise outras operações ou comandos (não estudados em sala) e realize outros tipos de técnicas de análise exploratória e pré-processamento de dados.#

# %% [markdown]
# __Diversos comandos utilizados durante esse notebook não foram vistos em sala. Mas vamos ver mais alguns:__

# %%
sns.countplot(x='language_code',data=df)
plt.title("Número de livros por língua")
plt.show()

# %% [markdown]
# __Isso não ficou muito bom, vamos tentar rotacionar os labels do eixo x!__

# %%
sns.countplot(x='language_code',data=df)
plt.title("Número de livros por língua")
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# __Restringindo ao quantitativo das 5 principais linguas__

# %%
sns.countplot(x='language_code',data=df, order= df.language_code.value_counts().iloc[:5].index)
plt.title("Top 5 do número de livros por língua")
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# __Bem melhor! Agora vamos plotar a matriz de correlações que fizemos acima de maneira mais visual usando o seaborn!__

# %%
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# __Além dos métodos vistos em sala para pré-processamento, temos também o RobustScaler, que lida bem com outliers, diferentemente do MinMaxScaler. Esse método remove a mediana e "escala" os dados de acordo com o a amplitude interquartílica. Mais informações: https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.RobustScaler.html__

# %%
from sklearn.preprocessing import RobustScaler


df['ratings_robust'] = RobustScaler().fit_transform(df['ratings_count'].values.reshape(-1,1))
df.sample(10)
# Out:
#        bookID                                              title  \
# 11615   39245                                  The Magic Journey
# 10736   35151        Mission to Moulokin (Icerigger Trilogy  #2)
# 5676    16892           A Hole in the World: An American Boyhood
# 7444    23315  The Scandal of Ulysses: The Life And Afterlife...
# 13         21               A Short History of Nearly Everything
# 6519    19496                                          Moonraker
# 12124   41491  Silent Night: The Remarkable Christmas Truce o...
# 5493    16372  The Mirror Crack'd from Side to Side (Miss Mar...
# 9382    30263         Every Which Way But Dead (The Hollows  #3)
# 2673     8073                  Cloudy With a Chance of Meatballs
#
#                            authors  average_rating        isbn         isbn13  \
# 11615             John     Nichols            3.91  0805063390  9780805063394
# 10736             Alan Dean Foster            3.86  0345333225  9780345333223
# 5676                Richard Rhodes            3.88  0700610383  9780700610389
# 7444                  Bruce Arnold            3.79  190414845X  9781904148456
# 13     Bill Bryson-William Roberts            4.20  076790818X  9780767908184
# 6519                   Ian Fleming            3.73  0141187565  9780141187563
# 12124            Stanley Weintraub            3.60  0684866226  9780684866222
# 5493               Agatha Christie            3.91  0007120982  9780007120987
# 9382                  Kim Harrison            4.29  006057299X  9780060572990
# 2673      Judi Barrett-Ron Barrett            4.16  0689707495  9780689707490
#
#       language_code  # num_pages  ratings_count  text_reviews_count  \
# 11615            en          528            433                  27
# 10736            en          294             34                   1
# 5676             en          288            180                  24
# 7444             en          350             12                   0
# 13               en          544         228522                8840
# 6519             en          247            115                  14
# 12124            en          256           3989                 169
# 5493             en          351          23249                 708
# 9382             en          501          58900                1185
# 2673             en           32         114747                1948
#
#             first_author  more_than_300  ratings_robust
# 11615   John     Nichols              1       -0.042389
# 10736   Alan Dean Foster              0       -0.128025
# 5676      Richard Rhodes              0       -0.096689
# 7444        Bruce Arnold              1       -0.132747
# 13           Bill Bryson              1       48.911627
# 6519         Ian Fleming              0       -0.110640
# 12124  Stanley Weintraub              0        0.720824
# 5493     Agatha Christie              1        4.854537
# 9382        Kim Harrison              1       12.506197
# 2673        Judi Barrett              0       24.492461

# %% [markdown]
# # O que você aprendeu sobre este dataset?#

# %% [markdown]
# 1) A maioria dos livros é de língua inglesa <br>
# 2) Não há dados faltantes <br>
# 3) Há inconsistências, como livros com 0 páginas. <br>
# 4) A maioria das pessoas deixam apenas uma avaliação em nota e não escrevem reviews em texto. <br>
# 5) Os rating variam de 0 a 5. <br>
# 6) A mediana do número de páginas de um livro no dataset é de 301. <br>
